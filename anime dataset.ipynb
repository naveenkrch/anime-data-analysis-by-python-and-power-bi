# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Anime.csv')
df1=pd.read_csv('Animation.csv')

# %%
df.head()
# Out:
#    animeID  name  studio  episodes  airing  rank  popularity  members  \
# 0        1     0       0        26   False    26          39   795733
# 1        5     0       0         1   False   164         449   197791
# 2        6     0       0        26   False   255         146   408548
# 3        7     0       0        26   False  2371        1171    79397
# 4        8     0       0        52   False  3544        3704    11708
#
#    favorites  reviewers  Animation_score
# 0      43460     405664             8.81
# 1        776     120243             8.41
# 2      10432     212537             8.30
# 3        537      32837             7.33
# 4         14       4894             7.03

# %%
df1.head()
# Out:
#    animeID                             name    source             producers  \
# 0        1                     Cowboy Bebop  Original         Bandai Visual
# 1        5  Cowboy Bebop: Tengoku no Tobira  Original               Sunrise
# 2        6                           Trigun     Manga  Victor Entertainment
# 3        7               Witch Hunter Robin  Original         Bandai Visual
# 4        8                   Bouken Ou Beet     Manga              TV Tokyo
#
#        genre          studio  episodes  airing  rank  popularity  members  \
# 0     Action         Sunrise      26.0   False    26          39   795733
# 1     Action           Bones       1.0   False   164         449   197791
# 2     Action        Madhouse      26.0   False   255         146   408548
# 3     Action         Sunrise      26.0   False  2371        1171    79397
# 4  Adventure  Toei Animation      52.0   False  3544        3704    11708
#
#    favorites  reviewers  Animation_score
# ...

# %%
df.isna().sum()
# Out:
# animeID            0
# name               0
# studio             0
# episodes           0
# airing             0
# rank               0
# popularity         0
# members            0
# favorites          0
# reviewers          0
# Animation_score    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# animeID            0
# episodes           0
# airing             0
# rank               0
# popularity         0
# members            0
# favorites          0
# reviewers          0
# Animation_score    0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# animeID         0
# name            0
# source          0
# producers    6217
# genre          62
# studio       5262
# dtype: int64

# %%
df1.drop(['episodes', 'Animation_score'], axis=1,inplace=True)

# %%
df1.drop(['favorites', 'reviewers'], axis=1,inplace=True)

# %%
df1.drop(['airing', 'rank'], axis=1,inplace=True)

# %%
df1.drop(['members', 'popularity'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    animeID  name  studio  episodes  airing  rank  popularity  members  \
# 0        1     0       0        26   False    26          39   795733
# 1        5     0       0         1   False   164         449   197791
# 2        6     0       0        26   False   255         146   408548
# 3        7     0       0        26   False  2371        1171    79397
# 4        8     0       0        52   False  3544        3704    11708
#
#    favorites  reviewers  Animation_score
# 0      43460     405664             8.81
# 1        776     120243             8.41
# 2      10432     212537             8.30
# 3        537      32837             7.33
# 4         14       4894             7.03

# %%
df1.head()
# Out:
#    animeID                             name    source             producers  \
# 0        1                     Cowboy Bebop  Original         Bandai Visual
# 1        5  Cowboy Bebop: Tengoku no Tobira  Original               Sunrise
# 2        6                           Trigun     Manga  Victor Entertainment
# 3        7               Witch Hunter Robin  Original         Bandai Visual
# 4        8                   Bouken Ou Beet     Manga              TV Tokyo
#
#        genre          studio  episodes  airing  rank  popularity  members  \
# 0     Action         Sunrise      26.0   False    26          39   795733
# 1     Action           Bones       1.0   False   164         449   197791
# 2     Action        Madhouse      26.0   False   255         146   408548
# 3     Action         Sunrise      26.0   False  2371        1171    79397
# 4  Adventure  Toei Animation      52.0   False  3544        3704    11708
#
#    favorites  reviewers  Animation_score
# ...

# %%
df1['genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Comedy', 'Slice of Life', 'Drama',
#        'Sci-Fi', 'Samurai', 'Game', 'Harem', 'Military', 'Space', 'Music',
#        'Supernatural', 'Historical', 'Magic', 'School', 'Mystery',
#        'Fantasy', 'Horror', 'Ecchi', 'Kids', 'Sports', 'Dementia',
#        'Romance', 'Police', 'Cars', 'Shounen', 'Demons', 'Parody',
#        'Psychological', 'Mecha', 'Shoujo', 'Super Power', 'Vampire',
#        'Martial Arts', 'Thriller', 'Seinen', 'Josei', nan], dtype=object)

# %%
df=df.merge(df1,on='animeID')

# %%
df.head()
# Out:
#    animeID  episodes  airing  rank  popularity  members  favorites  reviewers  \
# 0        1        26   False    26          39   795733      43460     405664
# 1        5         1   False   164         449   197791        776     120243
# 2        6        26   False   255         146   408548      10432     212537
# 3        7        26   False  2371        1171    79397        537      32837
# 4        8        52   False  3544        3704    11708         14       4894
#
#    Animation_score                             name    source  \
# 0             8.81                     Cowboy Bebop  Original
# 1             8.41  Cowboy Bebop: Tengoku no Tobira  Original
# 2             8.30                           Trigun     Manga
# 3             7.33               Witch Hunter Robin  Original
# 4             7.03                   Bouken Ou Beet     Manga
#
#               producers      genre          studio
# 0         Bandai Visual     Action         Sunrise
# ...

# %%
df.isna().sum()
# Out:
# animeID               0
# episodes              0
# airing                0
# rank                  0
# popularity            0
# members               0
# favorites             0
# reviewers             0
# Animation_score       0
# name                  0
# source                0
# producers          6215
# genre                62
# studio             5260
# dtype: int64

# %%
df['producers'].fillna('unknown', inplace=True)

# %%
df['studio'].fillna('unknown', inplace=True)

# %%
df['genre']=df['genre'].ffill()

# %%
df.to_excel('anime_main_data.xlsx')

# %%
df.isna().sum()
# Out:
# animeID            0
# episodes           0
# airing             0
# rank               0
# popularity         0
# members            0
# favorites          0
# reviewers          0
# Animation_score    0
# name               0
# source             0
# producers          0
# genre              0
# studio             0
# dtype: int64

# %%
df.head()
# Out:
#    animeID  episodes  airing  rank  popularity  members  favorites  reviewers  \
# 0        1        26   False    26          39   795733      43460     405664
# 1        5         1   False   164         449   197791        776     120243
# 2        6        26   False   255         146   408548      10432     212537
# 3        7        26   False  2371        1171    79397        537      32837
# 4        8        52   False  3544        3704    11708         14       4894
#
#    Animation_score                             name    source  \
# 0             8.81                     Cowboy Bebop  Original
# 1             8.41  Cowboy Bebop: Tengoku no Tobira  Original
# 2             8.30                           Trigun     Manga
# 3             7.33               Witch Hunter Robin  Original
# 4             7.03                   Bouken Ou Beet     Manga
#
#               producers      genre          studio
# 0         Bandai Visual     Action         Sunrise
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13628 entries, 0 to 13627
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   animeID          13628 non-null  int64
#  1   episodes         13628 non-null  int64
#  2   airing           13628 non-null  bool
#  3   rank             13628 non-null  int64
#  4   popularity       13628 non-null  int64
#  5   members          13628 non-null  int64
#  6   favorites        13628 non-null  int64
#  7   reviewers        13628 non-null  int64
#  8   Animation_score  13628 non-null  float64
#  9   name             13628 non-null  object
#  10  source           13628 non-null  object
#  11  producers        13628 non-null  object
#  12  genre            13628 non-null  object
#  13  studio           13628 non-null  object
# dtypes: bool(1), float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %%
sales_state = df.groupby(['name'], as_index=False)['popularity'].sum().sort_values(by='popularity', ascending=False).head(4)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'name',y= 'popularity')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 6
#       4 sns.barplot(data = sales_state, x = 'name',y= 'popularity')
#       5 for bars in ax.containers:
# ----> 6     ax.bar_label(bars)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2744, in Axes.bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2739 annotations = []
#    2741 for bar, err, dat, lbl in itertools.zip_longest(
#    2742         bars, errs, datavalues, labels
#    2743 ):
# -> 2744     (x0, y0), (x1, y1) = bar.get_bbox().get_points()
#    2745     xc, yc = (x0 + x1) / 2, (y0 + y1) / 2
#    2747     if orientation == "vertical":
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:879, in Rectangle.get_bbox(self)
#     877 """Return the `.Bbox`."""
#     878 x0, y0, x1, y1 = self._convert_units()
# ...

# %%
df.shape
# Out:
# (13628, 14)

# %%
sns.scatterplot(x=df['episodes'], y=df['rank'], hue=df['source'])
# Out:
# <Axes: xlabel='episodes', ylabel='rank'>

# %%
sns.barplot(x=df['name'], y=df['popularity']).head(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 sns.barplot(x=df['name'], y=df['popularity']).head(4)
#
# AttributeError: 'Axes' object has no attribute 'head'
# C:\Users\lnxhunt\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 9733 (\N{BLACK STAR}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\lnxhunt\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 9734 (\N{WHITE STAR}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\lnxhunt\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 9825 (\N{WHITE HEART SUIT}) missing from current font.
#   func(*args, **kwargs)
